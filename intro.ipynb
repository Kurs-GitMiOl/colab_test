# %% [markdown]
# <a href="https://colab.research.google.com/github/Kurs-GitMiOl/colab_test/blob/main/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello Coab")
# Out:
# Hello Coab

# %% [markdown]
# ### Tekst1
# ##Teskt2

# %% [markdown]
# ###Tekst3
